# %%
import numpy as np
import sklearn as skl
import pandas as pd
import sklearn.preprocessing
from sklearn import linear_model
from scipy import special
from sklearn.impute import SimpleImputer
from sklearn.metrics import mean_squared_error
import keras
from keras.layers import Dense, BatchNormalization
from keras.models import Sequential
from tensorflow.python.client import device_lib

np.random.seed(69) #fixing seed for reproducability

# %%
#print(device_lib.list_local_devices())

df_train = pd.read_csv("train.csv")
df_splitt = df_train['Sequence'].apply(lambda x: pd.Series(list(x))) #splitts the 4 mutators into individual columns.

#df_letters = pd.concat([df_train['Sequence'].apply(lambda x: pd.Series(list(x))), df_train['Active']],axis=1)

# %%
df_test = pd.read_csv("test.csv")
df_test_s = df_test['Sequence'].apply(lambda x: pd.Series(list(x)))

# %%
# define universe of possible input values
mutators = 'ACDEFGHIKLMNPQRSTUVWY' #abcdefghijklmnopqrstuvwxyz
#bjoqxz <-- these letters are missing

# define a mapping of chars to integers
char_to_int = dict((c, i) for i, c in enumerate(mutators))
int_to_char = dict((i, c) for i, c in enumerate(mutators))

# integer encode input data
#integer_encoded = [char_to_int[item] for item in df_letters[0]]
#print(integer_encoded)

# %%
df = np.zeros((112000, 4))
#Possibly the worst fucking way we could have done this. But fuckem.
for i in range(0,4):
    for j in range(0, 112000):
        temp = char_to_int[df_splitt.loc[j,i]]
        #df[j, i*19 + temp] = 1
        df[j, i] = temp

# %%
#Do the same with the test dataframe
df_cock = np.zeros((48000, 4))

for i in range(0,4):
    for j in range(0, 48000):
        temp = char_to_int[df_test_s.loc[j,i]]
        #df_cock[j, i*19 + temp] = 1
        df_cock[j, i] = temp

# %%
clf = skl.linear_model.RidgeCV(alphas=[0.01, 0.01, 0.1, 1, 10, 100, 1000, 2000,5000], cv=15)

labels = df_train['Active'].to_numpy()

#predict cocks:
#clf.fit(df,labels)
print('Done with fitting')
#predict_train = clf.predict(df)
#print('Done with prediction and error is: ', np.sqrt(np.mean((predict_train-labels)**2)))
#predict_cancer = clf.predict(df_cock)
#predict_cancer = np.where(predict_cancer > 0.5, 1, 0)
# Out:
# Done with fitting

# %%
#clf = skl.svm.LinearSVC(dual=False, class_weight='balanced')

#labels = df_train['Active'].to_numpy()

#predict cocks:
#clf.fit(df,labels)
print('Done with fitting')
#predict_train = clf.predict(df)
#print('Done with prediction and error is: ', np.sqrt(np.mean((predict_train-labels)**2)))
#predict_cancer = clf.predict(df_cock)
#predict_cancer = np.where(predict_cancer > 0.5, 1, 0)
# Out:
# Done with fitting

# %%
#np.savetxt('submission_sklearn.csv', predict_cancer, delimiter=',', fmt='%i')

# %%
#lets norm this shit
df_nn = (df+1)/21
df_cock_nn = (df_cock+1)/21

print(df_nn.max(), df_nn.min())
print(labels.max(), labels.min())
print(df_cock_nn.max(), df_cock_nn.min())
# Out:
# 1.0 0.047619047619047616
# 1 0
# 1.0 0.047619047619047616

# %%
#lets construct the neural net:
neuralNetwork = Sequential()
neuralNetwork.add(Dense(100, activation='relu', input_dim=4))
neuralNetwork.add(BatchNormalization())
neuralNetwork.add(Dense(100, activation='relu'))
neuralNetwork.add(BatchNormalization())
neuralNetwork.add(Dense(100, activation='relu'))
neuralNetwork.add(BatchNormalization())
neuralNetwork.add(Dense(1, activation='relu'))
neuralNetwork.add(BatchNormalization())
neuralNetwork.compile(loss = 'binary_crossentropy', optimizer = 'sgd', metrics=['accuracy'])

#fit the network to (for now the un-sparse matrix)
neuralNetwork.fit(df_nn, labels, epochs=100, batch_size=256, verbose=1)
# Out:
# Epoch 1/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6738 - accuracy: 0.9387
# Epoch 2/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.3390 - accuracy: 0.9550
# Epoch 3/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1555 - accuracy: 0.9624
# Epoch 4/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1566 - accuracy: 0.9624
# Epoch 5/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1577 - accuracy: 0.9624
# Epoch 6/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1495 - accuracy: 0.9624
# Epoch 7/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1605 - accuracy: 0.9624
# Epoch 8/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1487 - accuracy: 0.9624
# Epoch 9/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1574 - accuracy: 0.9624
# Epoch 10/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.1524 - accuracy: 0.9624
# Epoch 11/100
# 438/438 [==============================] - 1s 3ms/step - loss: 4.7713 - accuracy: 0.6427
# Epoch 12/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.0960 - accuracy: 0.9111
# Epoch 13/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.3360 - accuracy: 0.9624
# Epoch 14/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.3221 - accuracy: 0.9624
# Epoch 15/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2940 - accuracy: 0.9624
# Epoch 16/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.2797 - accuracy: 0.9624
# Epoch 17/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5784 - accuracy: 0.9425
# Epoch 18/100
# 438/438 [==============================] - 1s 3ms/step - loss: 12.5901 - accuracy: 0.1675
# Epoch 19/100
# 438/438 [==============================] - 1s 3ms/step - loss: 11.2303 - accuracy: 0.2538
# Epoch 20/100
# 438/438 [==============================] - 1s 3ms/step - loss: 8.9054 - accuracy: 0.4007
# Epoch 21/100
# 438/438 [==============================] - 1s 3ms/step - loss: 8.2642 - accuracy: 0.4433
# Epoch 22/100
# 438/438 [==============================] - 1s 3ms/step - loss: 6.8820 - accuracy: 0.5271
# Epoch 23/100
# 438/438 [==============================] - 1s 3ms/step - loss: 4.6275 - accuracy: 0.6796
# Epoch 24/100
# 438/438 [==============================] - 1s 3ms/step - loss: 5.0895 - accuracy: 0.6602
# Epoch 25/100
# 438/438 [==============================] - 1s 3ms/step - loss: 3.5340 - accuracy: 0.7599
# Epoch 26/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.2000 - accuracy: 0.8351
# Epoch 27/100
# 438/438 [==============================] - 1s 3ms/step - loss: 3.3165 - accuracy: 0.7720
# Epoch 28/100
# 438/438 [==============================] - 1s 3ms/step - loss: 3.0648 - accuracy: 0.7979
# Epoch 29/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.3475 - accuracy: 0.8437
# Epoch 30/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.0373 - accuracy: 0.8637
# Epoch 31/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.3869 - accuracy: 0.8407
# Epoch 32/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.0901 - accuracy: 0.8602
# Epoch 33/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.6612 - accuracy: 0.8908
# Epoch 34/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.7437 - accuracy: 0.8792
# Epoch 35/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.3377 - accuracy: 0.9106
# Epoch 36/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.3787 - accuracy: 0.9055
# Epoch 37/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.2885 - accuracy: 0.9133
# Epoch 38/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.1825 - accuracy: 0.9211
# Epoch 39/100
# 438/438 [==============================] - 1s 3ms/step - loss: 4.3512 - accuracy: 0.7051
# Epoch 40/100
# 438/438 [==============================] - 1s 3ms/step - loss: 5.1440 - accuracy: 0.6529
# Epoch 41/100
# 438/438 [==============================] - 1s 3ms/step - loss: 4.4069 - accuracy: 0.7031
# Epoch 42/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.8970 - accuracy: 0.8714
# Epoch 43/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6891 - accuracy: 0.9548
# Epoch 44/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.2049 - accuracy: 0.9194
# Epoch 45/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.3341 - accuracy: 0.9099
# Epoch 46/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.9998 - accuracy: 0.9340
# Epoch 47/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.5545 - accuracy: 0.8941
# Epoch 48/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.1357 - accuracy: 0.8563
# Epoch 49/100
# 438/438 [==============================] - 1s 3ms/step - loss: 5.7475 - accuracy: 0.6118
# Epoch 50/100
# 438/438 [==============================] - 1s 3ms/step - loss: 5.1229 - accuracy: 0.6542
# Epoch 51/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.6622 - accuracy: 0.8193
# Epoch 52/100
# 438/438 [==============================] - 1s 3ms/step - loss: 1.6077 - accuracy: 0.8925
# Epoch 53/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.9358 - accuracy: 0.9379
# Epoch 54/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.8343 - accuracy: 0.9449
# Epoch 55/100
# 438/438 [==============================] - 1s 3ms/step - loss: 2.6683 - accuracy: 0.8204
# Epoch 56/100
# 438/438 [==============================] - 1s 3ms/step - loss: 3.1440 - accuracy: 0.7861
# Epoch 57/100
# 438/438 [==============================] - 1s 3ms/step - loss: 3.3739 - accuracy: 0.7679
# Epoch 58/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.7587 - accuracy: 0.9495
# Epoch 59/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6258 - accuracy: 0.9593
# Epoch 60/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6122 - accuracy: 0.9603
# Epoch 61/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6081 - accuracy: 0.9605
# Epoch 62/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6097 - accuracy: 0.9604
# Epoch 63/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6057 - accuracy: 0.9607
# Epoch 64/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6018 - accuracy: 0.9609
# Epoch 65/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5953 - accuracy: 0.9613
# Epoch 66/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6017 - accuracy: 0.9610
# Epoch 67/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5992 - accuracy: 0.9611
# Epoch 68/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5942 - accuracy: 0.9614
# Epoch 69/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.6025 - accuracy: 0.9609
# Epoch 70/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5900 - accuracy: 0.9617
# Epoch 71/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5839 - accuracy: 0.9621
# Epoch 72/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5818 - accuracy: 0.9623
# Epoch 73/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5825 - accuracy: 0.9622
# Epoch 74/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5835 - accuracy: 0.9622
# Epoch 75/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5836 - accuracy: 0.9622
# Epoch 76/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5811 - accuracy: 0.9623
# Epoch 77/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5822 - accuracy: 0.9622
# Epoch 78/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5825 - accuracy: 0.9622
# Epoch 79/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5829 - accuracy: 0.9622
# Epoch 80/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5815 - accuracy: 0.9623
# Epoch 81/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5837 - accuracy: 0.9622
# Epoch 82/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5815 - accuracy: 0.9623
# Epoch 83/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5839 - accuracy: 0.9621
# Epoch 84/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5824 - accuracy: 0.9622
# Epoch 85/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5817 - accuracy: 0.9623
# Epoch 86/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5801 - accuracy: 0.9624
# Epoch 87/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5799 - accuracy: 0.9624
# Epoch 88/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5799 - accuracy: 0.9624
# Epoch 89/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5805 - accuracy: 0.9624
# Epoch 90/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5798 - accuracy: 0.9624
# Epoch 91/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5806 - accuracy: 0.9624
# Epoch 92/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5806 - accuracy: 0.9624
# Epoch 93/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5808 - accuracy: 0.9623
# Epoch 94/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5806 - accuracy: 0.9624
# Epoch 95/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5806 - accuracy: 0.9624
# Epoch 96/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5801 - accuracy: 0.9624
# Epoch 97/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5802 - accuracy: 0.9624
# Epoch 98/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5791 - accuracy: 0.9625
# Epoch 99/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5804 - accuracy: 0.9624
# Epoch 100/100
# 438/438 [==============================] - 1s 3ms/step - loss: 0.5802 - accuracy: 0.9624

# %%
predict_cancer_nn = neuralNetwork.predict(df_cock_nn)
print(predict_cancer_nn)
predict_cancer_nn = (predict_cancer_nn <= -8)

predict_cancer_nn = pd.DataFrame(predict_cancer_nn.astype('int'))
predict_cancer_nn.to_csv('predictions.csv', header = False, index = False)
# Out:
# [[ -3.786911 ]
#  [ -5.317009 ]
#  [ -5.2450027]
#  ...
#  [ -4.6423035]
#  [ -4.4252777]
#  [-39.016785 ]]

# %%
print(predict_cancer_nn.max())
print(predict_cancer_nn.mean())

predict_train = neuralNetwork.predict(df_nn)
predict_train_nn = pd.DataFrame(predict_train.astype('float'))
print(predict_train_nn.max())
print(predict_train_nn.min())
# Out:
# 0    1
# dtype: int32
# 0    0.000125
# dtype: float64
# 0    73.095268
# dtype: float64
# 0   -61.916786
# dtype: float64
